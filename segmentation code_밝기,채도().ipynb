# %% [markdown]
# ### npy load

# %%
import tensorflow.compat.v1 as tf1
# import tensorflow as tf2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"
config = tf1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.05
session = tf1.Session(config=config)
# Out:
# 2024-01-21 10:20:26.987535: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-21 10:20:27.083567: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-21 10:20:29.021488: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-21 10:20:33.680291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2016 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:86:00.0, compute capability: 8.0

# %%
import matplotlib.pyplot as plt
import cv2, os, glob
import numpy as np
from PIL import Image

# %%
train_images =  np.load('/home/nas/data/eunju/Industrial/leather/train_images.npy')
train_labels =  np.load('/home/nas/data/eunju/Industrial/leather/train_labels.npy')

val_images =  np.load('/home/nas/data/eunju/Industrial/leather/val_images.npy')
val_labels =  np.load('/home/nas/data/eunju/Industrial/leather/val_labels.npy')

test_images =  np.load('/home/nas/data/eunju/Industrial/leather/test_images.npy')
test_labels =  np.load('/home/nas/data/eunju/Industrial/leather/test_labels.npy')

# %% [markdown]
# ### 6:2:2 비율
# - 총 92개

# %%
print("train_images:", train_images.shape)
print("train_labels:", train_labels.shape)
print("test_images: ", test_images.shape)
print("test_labels: ", test_labels.shape)
print("val_images:  ", val_images.shape)
print("val_labels:  ", val_labels.shape)
# Out:
# train_images: (55, 256, 256, 3)
# train_labels: (55, 256, 256)
# test_images:  (19, 256, 256, 3)
# test_labels:  (19, 256, 256)
# val_images:   (18, 256, 256, 3)
# val_labels:   (18, 256, 256)

# %% [markdown]
# ### 데이터 회전 추가

# %%
import numpy as np

# 회전 함수
def rotate_images_labels(images, labels, rotation_angle):
    rotated_images = [np.rot90(img, k=rotation_angle // 90) for img in images]
    rotated_labels = [np.rot90(lbl, k=rotation_angle // 90) for lbl in labels]

    return rotated_images, rotated_labels

# 회전할 각도 리스트
rotation_angles = [90, 180, 270]

# 데이터 회전
for angle in rotation_angles:
    rotated_train_images, rotated_train_labels = rotate_images_labels(train_images, train_labels, rotation_angle=angle)
    rotated_val_images, rotated_val_labels = rotate_images_labels(val_images, val_labels, rotation_angle=angle)
    rotated_test_images, rotated_test_labels = rotate_images_labels(test_images, test_labels, rotation_angle=angle)

    # 데이터 추가하기
    train_images = np.concatenate([train_images, rotated_train_images], axis=0)
    train_labels = np.concatenate([train_labels, rotated_train_labels], axis=0)

    val_images = np.concatenate([val_images, rotated_val_images], axis=0)
    val_labels = np.concatenate([val_labels, rotated_val_labels], axis=0)

# 데이터 차원 확인
print("Train Images Shape:", train_images.shape)
print("Train Labels Shape:", train_labels.shape)

print("Validation Images Shape:", val_images.shape)
print("Validation Labels Shape:", val_labels.shape)
# Out:
# Train Images Shape: (440, 256, 256, 3)
# Train Labels Shape: (440, 256, 256)
# Validation Images Shape: (144, 256, 256, 3)
# Validation Labels Shape: (144, 256, 256)

# %% [markdown]
# # 밝기,채도 조정

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# 이미지 배열 가져오기
image_np = train_images[243]

# Matplotlib의 이미지를 NumPy 배열로 변환
image_np = (image_np * 255).astype(np.uint8)

# 밝기와 채도를 조절할 계수 설정
brightness_factor = 2.0
saturation_factor = 0.7

# 밝기 조절
brightened_image = cv2.convertScaleAbs(image_np, alpha=brightness_factor, beta=0)

# 이미지를 HSV로 변환
img_hsv = cv2.cvtColor(brightened_image, cv2.COLOR_BGR2HSV)

# 채도 조절
img_hsv[:, :, 1] = np.clip(img_hsv[:, :, 1] * saturation_factor, 0, 255)

# HSV를 다시 BGR로 변환
saturated_image = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2BGR) / 255.0

# 결과 이미지 표시
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image_np)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(brightened_image)
plt.title('Brightened Image')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(saturated_image)
plt.title('Brightened and Saturated Image')
plt.axis('off')

plt.show()

# %% [markdown]
# ### 실행함수

# %%
import cv2
import numpy as np

def adjust_brightness(images, brightness_factor):
    adjusted_images = []
    
    for img in images:
        # 이미지를 NumPy 배열로 변환
        img_np = (img * 255).astype(np.uint8)
        
        # 밝기 조절
        adjusted_img = cv2.convertScaleAbs(img_np, alpha=brightness_factor, beta=0)
        
        # 조절된 이미지를 다시 [0, 1] 범위로 스케일링
        adjusted_img = adjusted_img / 255.0
        
        adjusted_images.append(adjusted_img)
    
    return np.array(adjusted_images)

# 밝기를 조절할 계수 설정
brightness_factor = 2.0

# train_images 밝기 조절
train_images = adjust_brightness(train_images, brightness_factor)

# val_images 밝기 조절
val_images = adjust_brightness(val_images, brightness_factor)

# %% [markdown]
# ### image 확인

# %%
plt.subplot(131); plt.imshow(train_images[400]); plt.title("image") ; plt.axis(False)
plt.subplot(132); plt.imshow(train_labels[400]); plt.title("label") ; plt.axis(False)
plt.subplot(133); plt.imshow(train_images[400]); plt.axis(False)
plt.subplot(133); plt.imshow(train_labels[400], alpha=0.5) ;plt.title('overlab') ; plt.axis(False)
plt.tight_layout() ; plt.show()

# %%
import random

# 랜덤 16개 선택
random_indices = random.sample(range(test_images.shape[0]), 16)
fig, axs = plt.subplots(4, 4, figsize=(5, 5))

for i, ax in enumerate(axs.flat):
    ax.imshow(test_images[random_indices[i]])
    ax.axis('off')
    
plt.suptitle("leather Images")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 네트워크

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model

input_shape = (256, 256, 3)
inputs = Input(shape=input_shape)

# Encoder
conv1 = Conv2D(8, (3, 3), activation='relu', padding='same')(inputs)
conv1 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(4, 4))(conv1)

conv2 = Conv2D(16, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

# Middle
conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool2)
conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv5)

# Decoder
up8 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv2], axis=-1)
conv8 = Conv2D(16, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([UpSampling2D(size=(4, 4))(conv8), conv1], axis=-1)
conv9 = Conv2D(8, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# 2024-01-21 10:21:14.574529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2016 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:86:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 8)          224       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 8)          584       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 8)            0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 16)           1168      ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 16)           2320      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 16)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)           4640      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 32)           9248      ['conv2d_4[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 64, 64, 32)           0         ['conv2d_5[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 64, 64, 48)           0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 16)           6928      ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 16)           2320      ['conv2d_6[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 256, 256, 16)         0         ['conv2d_7[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 256, 256, 24)         0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 8)          1736      ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 8)          584       ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 1)          9         ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 29761 (116.25 KB)
# Trainable params: 29761 (116.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, validation_data=(val_images, val_labels), epochs=500, batch_size=16)
# Out:
# Epoch 1/500
# 2024-01-21 10:21:27.267266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-01-21 10:21:31.201328: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-21 10:21:36.024762: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ef909eb7a70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-21 10:21:36.024832: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB, Compute Capability 8.0
# 2024-01-21 10:21:36.034940: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-21 10:21:36.184541: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-21 10:21:36.288049: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 28/28 [==============================] - 36s 338ms/step - loss: 0.4185 - accuracy: 0.9355 - val_loss: 0.2330 - val_accuracy: 0.9849
# Epoch 2/500
# 2024-01-21 10:21:54.714857: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 28/28 [==============================] - 2s 58ms/step - loss: 0.1269 - accuracy: 0.9918 - val_loss: 0.2325 - val_accuracy: 0.9849
# Epoch 3/500
# 28/28 [==============================] - 2s 58ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2325 - val_accuracy: 0.9849
# Epoch 4/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2325 - val_accuracy: 0.9849
# Epoch 5/500
# 28/28 [==============================] - 1s 53ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2324 - val_accuracy: 0.9849
# Epoch 6/500
# 28/28 [==============================] - 1s 52ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2324 - val_accuracy: 0.9849
# Epoch 7/500
# 28/28 [==============================] - 1s 51ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2324 - val_accuracy: 0.9849
# Epoch 8/500
# 28/28 [==============================] - 1s 45ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2324 - val_accuracy: 0.9849
# Epoch 9/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.1268 - accuracy: 0.9918 - val_loss: 0.2324 - val_accuracy: 0.9849
# Epoch 10/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.1157 - accuracy: 0.9918 - val_loss: 0.1129 - val_accuracy: 0.9849
# Epoch 11/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0490 - accuracy: 0.9918 - val_loss: 0.0813 - val_accuracy: 0.9849
# Epoch 12/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0468 - accuracy: 0.9918 - val_loss: 0.0809 - val_accuracy: 0.9849
# Epoch 13/500
# 28/28 [==============================] - 1s 51ms/step - loss: 0.0469 - accuracy: 0.9918 - val_loss: 0.0758 - val_accuracy: 0.9849
# Epoch 14/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0465 - accuracy: 0.9918 - val_loss: 0.0796 - val_accuracy: 0.9849
# Epoch 15/500
# 28/28 [==============================] - 1s 50ms/step - loss: 0.0464 - accuracy: 0.9918 - val_loss: 0.0814 - val_accuracy: 0.9849
# Epoch 16/500
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0460 - accuracy: 0.9918 - val_loss: 0.0769 - val_accuracy: 0.9849
# Epoch 17/500
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0453 - accuracy: 0.9918 - val_loss: 0.0742 - val_accuracy: 0.9849
# Epoch 18/500
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0439 - accuracy: 0.9918 - val_loss: 0.0706 - val_accuracy: 0.9849
# Epoch 19/500
# 28/28 [==============================] - 1s 49ms/step - loss: 0.0418 - accuracy: 0.9918 - val_loss: 0.0797 - val_accuracy: 0.9849
# Epoch 20/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0485 - accuracy: 0.9918 - val_loss: 0.0805 - val_accuracy: 0.9849
# Epoch 21/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0434 - accuracy: 0.9918 - val_loss: 0.0700 - val_accuracy: 0.9849
# Epoch 22/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0416 - accuracy: 0.9918 - val_loss: 0.0692 - val_accuracy: 0.9849
# Epoch 23/500
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0377 - accuracy: 0.9918 - val_loss: 0.0663 - val_accuracy: 0.9850
# Epoch 24/500
# 28/28 [==============================] - 1s 50ms/step - loss: 0.0394 - accuracy: 0.9918 - val_loss: 0.0688 - val_accuracy: 0.9849
# Epoch 25/500
# 28/28 [==============================] - 2s 54ms/step - loss: 0.
500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.0222 - val_accuracy: 0.9924
# Epoch 61/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 0.0210 - val_accuracy: 0.9927
# Epoch 62/500
# 28/28 [==============================] - 1s 51ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.0276 - val_accuracy: 0.9916
# Epoch 63/500
# 28/28 [==============================] - 1s 51ms/step - loss: 0.0103 - accuracy: 0.9957 - val_loss: 0.0237 - val_accuracy: 0.9926
# Epoch 64/500
# 28/28 [==============================] - 1s 50ms/step - loss: 0.0098 - accuracy: 0.9960 - val_loss: 0.0203 - val_accuracy: 0.9928
# Epoch 65/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0097 - accuracy: 0.9960 - val_loss: 0.0237 - val_accuracy: 0.9927
# Epoch 66/500
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0098 - accuracy: 0.9960 - val_loss: 0.0258 - val_accuracy: 0.9921
# Epoch 67/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 0.0212 - val_accuracy: 0.9929
# Epoch 68/500
# 28/28 [==============================] - 1s 54ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.0203 - val_accuracy: 0.9926
# Epoch 69/500
# 28/28 [==============================] - 1s 52ms/step - loss: 0.0101 - accuracy: 0.9959 - val_loss: 0.0219 - val_accuracy: 0.9929
# Epoch 70/500
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0093 - accuracy: 0.9962 - val_loss: 0.0214 - val_accuracy: 0.9928
# Epoch 71/500
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0091 - accuracy: 0.9962 - val_loss: 0.0210 - val_accuracy: 0.9932
# Epoch 72/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0092 - accuracy: 0.9962 - val_loss: 0.0199 - val_accuracy: 0.9930
# Epoch 73/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0200 - val_accuracy: 0.9932
# Epoch 74/500
# 28/28 [==============================] - 1s 51ms/step - loss: 0.0087 - accuracy: 0.9964 - val_loss: 0.0219 - val_accuracy: 0.9929
# Epoch 75/500
# 28/28 [==============================] - 1s 54ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0225 - val_accuracy: 0.9932
# Epoch 76/500
# 28/28 [==============================] - 1s 50ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.0203 - val_accuracy: 0.9932
# Epoch 77/500
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0210 - val_accuracy: 0.9932
# Epoch 78/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0237 - val_accuracy: 0.9930
# Epoch 79/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0214 - val_accuracy: 0.9933
# Epoch 80/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0089 - accuracy: 0.9963 - val_loss: 0.0223 - val_accuracy: 0.9929
# Epoch 81/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0094 - accuracy: 0.9962 - val_loss: 0.0204 - val_accuracy: 0.9932
# Epoch 82/500
# 28/28 [==============================] - 1s 50ms/step - loss: 0.0089 - accuracy: 0.9963 - val_loss: 0.0215 - val_accuracy: 0.9933
# Epoch 83/500
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0204 - val_accuracy: 0.9933
# Epoch 84/500
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0080 - accuracy: 0.9967 - val_loss: 0.0238 - val_accuracy: 0.9931
# Epoch 85/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0076 - accuracy: 0.9969 - val_loss: 0.0208 - val_accuracy: 0.9933
# Epoch 86/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0076 - accuracy: 0.9968 - val_loss: 0.0220 - val_accuracy: 0.9931
# Epoch 87/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0225 - val_accuracy: 0.9931
# Epoch 88/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 0.0221 - val_accuracy: 0.9931
# Epoch 89/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0075 - accuracy: 0.9969 - val_loss: 0.0240 - val_accuracy: 0.9932
# Epoch 90/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0073 - accuracy: 0.9970 - val_loss: 0.0200 - val_accuracy: 0.9932
# Epoch 91/500
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0250 - val_accuracy: 0.9931
# Epoch 92/500
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0203 - val_accuracy: 0.9930
# Epoch 93/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0207 - val_accuracy: 0.9933
# Epoch 94/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0250 - val_accuracy: 0.9932
# Epoch 95/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0254 - val_accuracy: 0.9930
# Epoch 96/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0070 - accuracy: 0.9971 - val_loss: 0.0212 - val_accuracy: 0.9934
# Epoch 97/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0250 - val_accuracy: 0.9933
# Epoch 98/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0221 - val_accuracy: 0.9933
# Epoch 99/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0238 - val_accuracy: 0.9932
# Epoch 100/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0252 - val_accuracy: 0.9932
# Epoch 101/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0216 - val_accuracy: 0.9933
# Epoch 102/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0241 - val_accuracy: 0.9933
# Epoch 103/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0255 - val_accuracy: 0.9933
# Epoch 104/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.0309 - val_accuracy: 0.9923
# Epoch 105/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0256 - val_accuracy: 0.9933
# Epoch 106/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0252 - val_accuracy: 0.9933
# Epoch 107/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.0263 - val_accuracy: 0.9932
# Epoch 108/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.0271 - val_accuracy: 0.9931
# Epoch 109/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.0321 - val_accuracy: 0.9927
# Epoch 110/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0261 - val_accuracy: 0.9932
# Epoch 111/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0247 - val_accuracy: 0.9932
# Epoch 112/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0258 - val_accuracy: 0.9931
# Epoch 113/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0271 - val_accuracy: 0.9931
# Epoch 114/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0290 - val_accuracy: 0.9930
# Epoch 115/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.0262 - val_accuracy: 0.9930
# Epoch 116/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0291 - val_accuracy: 0.9931
# Epoch 117/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.0283 - val_accuracy: 0.9930
# Epoch 118/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0049 - accuracy: 0.9980 - val_loss: 0.0305 - val_accuracy: 0.9928
# Epoch 119/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0246 - val_accuracy: 0.9932
# Epoch 120/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0246 - val_accuracy: 0.9929
# Epoch 121/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0270 - val_accuracy: 0.9932
# Epoch 122/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 0.0286 - val_accuracy: 0.9932
# Epoch 123/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0319 - val_accuracy: 0.9929
# Epoch 124/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0286 - val_accuracy: 0.9931
# Epoch 125/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0315 - val_accuracy: 0.9930
# Epoch 126/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0310 - val_accuracy: 0.9931
# Epoch 127/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0286 - val_accuracy: 0.9932
# Epoch 128/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0337 - val_accuracy: 0.9930
# Epoch 129/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0279 - val_accuracy: 0.9929
# Epoch 130/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0298 - val_accuracy: 0.9930
# Epoch 131/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0311 - val_accuracy: 0.9931
# Epoch 132/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.0317 - val_accuracy: 0.9930
# Epoch 133/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0321 - val_accuracy: 0.9929
# Epoch 134/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0339 - val_accuracy: 0.9928
# Epoch 135/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0318 - val_accuracy: 0.9931
# Epoch 136/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0292 - val_accuracy: 0.9931
# Epoch 137/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0312 - val_accuracy: 0.9931
# Epoch 138/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0311 - val_accuracy: 0.9932
# Epoch 139/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0039 - accuracy: 0.9984 - val_loss: 0.0329 - val_accuracy: 0.9930
# Epoch 140/500
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0325 - val_accuracy: 0.9931
# Epoch 141/500
# 28/28 [==============================] - 1s 49ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0353 - val_accuracy: 0.9931
# Epoch 142/500
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0346 - val_accuracy: 0.9931
# Epoch 143/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0351 - val_accuracy: 0.9930
# Epoch 144/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0346 - val_accuracy: 0.9929
# Epoch 145/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0314 - val_accuracy: 0.9931
# Epoch 146/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0339 - val_accuracy: 0.9931
# Epoch 147/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0363 - val_accuracy: 0.9930
# Epoch 148/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0333 - val_accuracy: 0.9931
# Epoch 149/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0335 - val_accuracy: 0.9929
# Epoch 150/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0327 - val_accuracy: 0.9930
# Epoch 151/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0364 - val_accuracy: 0.9930
# Epoch 152/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.0352 - val_accuracy: 0.9931
# Epoch 153/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0357 - val_accuracy: 0.9930
# Epoch 154/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0357 - val_accuracy: 0.9931
# Epoch 155/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0381 - val_accuracy: 0.9930
# Epoch 156/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.0355 - val_accuracy: 0.9931
# Epoch 157/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0350 - val_accuracy: 0.9929
# Epoch 158/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0354 - val_accuracy: 0.9931
# Epoch 159/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0375 - val_accuracy: 0.9931
# Epoch 160/500
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0359 - val_accuracy: 0.9930
# Epoch 161/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0028 - accuracy: 0.9988 - val_loss: 0.0355 - val_accuracy: 0.9931
# Epoch 162/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0393 - val_accuracy: 0.9930
# Epoch 163/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0396 - val_accuracy: 0.9930
# Epoch 164/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0379 - val_accuracy: 0.9930
# Epoch 165/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.0368 - val_accuracy: 0.9931
# Epoch 166/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0392 - val_accuracy: 0.9930
# Epoch 167/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0382 - val_accuracy: 0.9928
# Epoch 168/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.0364 - val_accuracy: 0.9929
# Epoch 169/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0372 - val_accuracy: 0.9930
# Epoch 170/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0382 - val_accuracy: 0.9931
# Epoch 171/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.0352 - val_accuracy: 0.9930
# Epoch 172/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0384 - val_accuracy: 0.9930
# Epoch 173/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0391 - val_accuracy: 0.9931
# Epoch 174/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0392 - val_accuracy: 0.9931
# Epoch 175/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0401 - val_accuracy: 0.9930
# Epoch 176/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.0392 - val_accuracy: 0.9929
# Epoch 177/500
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0415 - val_accuracy: 0.9928
# Epoch 178/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0411 - val_accuracy: 0.9930
# Epoch 179/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0437 - val_accuracy: 0.9930
# Epoch 180/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0444 - val_accuracy: 0.9929
# Epoch 181/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0389 - val_accuracy: 0.9931
# Epoch 182/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.0378 - val_accuracy: 0.9930
# Epoch 183/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0404 - val_accuracy: 0.9931
# Epoch 184/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0427 - val_accuracy: 0.9931
# Epoch 185/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0419 - val_accuracy: 0.9930
# Epoch 186/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0432 - val_accuracy: 0.9930
# Epoch 187/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0434 - val_accuracy: 0.9930
# Epoch 188/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0397 - val_accuracy: 0.9930
# Epoch 189/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0372 - val_accuracy: 0.9931
# Epoch 190/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0412 - val_accuracy: 0.9931
# Epoch 191/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0434 - val_accuracy: 0.9930
# Epoch 192/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0439 - val_accuracy: 0.9931
# Epoch 193/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0466 - val_accuracy: 0.9930
# Epoch 194/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0468 - val_accuracy: 0.9930
# Epoch 195/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0449 - val_accuracy: 0.9930
# Epoch 196/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0456 - val_accuracy: 0.9931
# Epoch 197/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0451 - val_accuracy: 0.9931
# Epoch 198/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0502 - val_accuracy: 0.9928
# Epoch 199/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0440 - val_accuracy: 0.9927
# Epoch 200/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.0412 - val_accuracy: 0.9930
# Epoch 201/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0445 - val_accuracy: 0.9931
# Epoch 202/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0480 - val_accuracy: 0.9930
# Epoch 203/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0451 - val_accuracy: 0.9931
# Epoch 204/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0453 - val_accuracy: 0.9930
# Epoch 205/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0470 - val_accuracy: 0.9930
# Epoch 206/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0448 - val_accuracy: 0.9931
# Epoch 207/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0492 - val_accuracy: 0.9929
# Epoch 208/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0472 - val_accuracy: 0.9930
# Epoch 209/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0480 - val_accuracy: 0.9931
# Epoch 210/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0458 - val_accuracy: 0.9931
# Epoch 211/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0465 - val_accuracy: 0.9930
# Epoch 212/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0496 - val_accuracy: 0.9930
# Epoch 213/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0438 - val_accuracy: 0.9930
# Epoch 214/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0476 - val_accuracy: 0.9930
# Epoch 215/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0492 - val_accuracy: 0.9930
# Epoch 216/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0489 - val_accuracy: 0.9931
# Epoch 217/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0491 - val_accuracy: 0.9930
# Epoch 218/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0449 - val_accuracy: 0.9931
# Epoch 219/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0458 - val_accuracy: 0.9930
# Epoch 220/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0481 - val_accuracy: 0.9931
# Epoch 221/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0480 - val_accuracy: 0.9931
# Epoch 222/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0476 - val_accuracy: 0.9931
# Epoch 223/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0499 - val_accuracy: 0.9930
# Epoch 224/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0470 - val_accuracy: 0.9930
# Epoch 225/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0479 - val_accuracy: 0.9931
# Epoch 226/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0489 - val_accuracy: 0.9931
# Epoch 227/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0463 - val_accuracy: 0.9931
# Epoch 228/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0449 - val_accuracy: 0.9931
# Epoch 229/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0510 - val_accuracy: 0.9930
# Epoch 230/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0446 - val_accuracy: 0.9932
# Epoch 231/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0493 - val_accuracy: 0.9931
# Epoch 232/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0523 - val_accuracy: 0.9930
# Epoch 233/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0565 - val_accuracy: 0.9928
# Epoch 234/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0485 - val_accuracy: 0.9931
# Epoch 235/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0539 - val_accuracy: 0.9930
# Epoch 236/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.0374 - val_accuracy: 0.9928
# Epoch 237/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0403 - val_accuracy: 0.9930
# Epoch 238/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0410 - val_accuracy: 0.9931
# Epoch 239/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0477 - val_accuracy: 0.9931
# Epoch 240/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0501 - val_accuracy: 0.9931
# Epoch 241/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0523 - val_accuracy: 0.9931
# Epoch 242/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0542 - val_accuracy: 0.9930
# Epoch 243/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0547 - val_accuracy: 0.9931
# Epoch 244/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0559 - val_accuracy: 0.9931
# Epoch 245/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0544 - val_accuracy: 0.9931
# Epoch 246/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0546 - val_accuracy: 0.9931
# Epoch 247/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0527 - val_accuracy: 0.9930
# Epoch 248/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0576 - val_accuracy: 0.9928
# Epoch 249/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0501 - val_accuracy: 0.9930
# Epoch 250/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0491 - val_accuracy: 0.9932
# Epoch 251/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0494 - val_accuracy: 0.9930
# Epoch 252/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0480 - val_accuracy: 0.9931
# Epoch 253/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0494 - val_accuracy: 0.9931
# Epoch 254/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0508 - val_accuracy: 0.9930
# Epoch 255/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0515 - val_accuracy: 0.9932
# Epoch 256/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0561 - val_accuracy: 0.9931
# Epoch 257/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0560 - val_accuracy: 0.9930
# Epoch 258/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0539 - val_accuracy: 0.9931
# Epoch 259/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0566 - val_accuracy: 0.9931
# Epoch 260/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0568 - val_accuracy: 0.9931
# Epoch 261/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0574 - val_accuracy: 0.9929
# Epoch 262/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0493 - val_accuracy: 0.9931
# Epoch 263/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0552 - val_accuracy: 0.9930
# Epoch 264/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0529 - val_accuracy: 0.9931
# Epoch 265/500
# 28/28 [==============================] - 1s 43ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0537 - val_accuracy: 0.9931
# Epoch 266/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0524 - val_accuracy: 0.9931
# Epoch 267/500
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0525 - val_accuracy: 0.9929
# Epoch 268/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0476 - val_accuracy: 0.9930
# Epoch 269/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0524 - val_accuracy: 0.9931
# Epoch 270/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0553 - val_accuracy: 0.9930
# Epoch 271/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0550 - val_accuracy: 0.9931
# Epoch 272/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0561 - val_accuracy: 0.9930
# Epoch 273/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0561 - val_accuracy: 0.9931
# Epoch 274/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0583 - val_accuracy: 0.9930
# Epoch 275/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0568 - val_accuracy: 0.9930
# Epoch 276/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0580 - val_accuracy: 0.9930
# Epoch 277/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0578 - val_accuracy: 0.9930
# Epoch 278/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0534 - val_accuracy: 0.9930
# Epoch 279/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0462 - val_accuracy: 0.9928
# Epoch 280/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0518 - val_accuracy: 0.9931
# Epoch 281/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0586 - val_accuracy: 0.9930
# Epoch 282/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0570 - val_accuracy: 0.9931
# Epoch 283/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0584 - val_accuracy: 0.9931
# Epoch 284/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0581 - val_accuracy: 0.9929
# Epoch 285/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0578 - val_accuracy: 0.9930
# Epoch 286/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0576 - val_accuracy: 0.9930
# Epoch 287/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0499 - val_accuracy: 0.9930
# Epoch 288/500
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0479 - val_accuracy: 0.9931
# Epoch 289/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0498 - val_accuracy: 0.9932
# Epoch 290/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0546 - val_accuracy: 0.9931
# Epoch 291/500
# 28/28 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0513 - val_accuracy: 0.9929
# Epoch 292/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 293/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0521 - val_accuracy: 0.9931
# Epoch 294/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0575 - val_accuracy: 0.9931
# Epoch 295/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0595 - val_accuracy: 0.9930
# Epoch 296/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0594 - val_accuracy: 0.9931
# Epoch 297/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0609 - val_accuracy: 0.9931
# Epoch 298/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0636 - val_accuracy: 0.9930
# Epoch 299/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0594 - val_accuracy: 0.9931
# Epoch 300/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0584 - val_accuracy: 0.9930
# Epoch 301/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0599 - val_accuracy: 0.9930
# Epoch 302/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0592 - val_accuracy: 0.9930
# Epoch 303/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0624 - val_accuracy: 0.9929
# Epoch 304/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0552 - val_accuracy: 0.9930
# Epoch 305/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0561 - val_accuracy: 0.9931
# Epoch 306/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0582 - val_accuracy: 0.9931
# Epoch 307/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0581 - val_accuracy: 0.9930
# Epoch 308/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0520 - val_accuracy: 0.9930
# Epoch 309/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0509 - val_accuracy: 0.9931
# Epoch 310/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0591 - val_accuracy: 0.9930
# Epoch 311/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0583 - val_accuracy: 0.9931
# Epoch 312/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0566 - val_accuracy: 0.9931
# Epoch 313/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.0538 - val_accuracy: 0.9931
# Epoch 314/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0536 - val_accuracy: 0.9931
# Epoch 315/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0606 - val_accuracy: 0.9930
# Epoch 316/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0611 - val_accuracy: 0.9930
# Epoch 317/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0627 - val_accuracy: 0.9931
# Epoch 318/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0600 - val_accuracy: 0.9931
# Epoch 319/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0646 - val_accuracy: 0.9927
# Epoch 320/500
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0495 - val_accuracy: 0.9930
# Epoch 321/500
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0527 - val_accuracy: 0.9931
# Epoch 322/500
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0586 - val_accuracy: 0.9930
# Epoch 323/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0590 - val_accuracy: 0.9931
# Epoch 324/500
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0607 - val_accuracy: 0.9931
# Epoch 325/500
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0687 - val_accuracy: 0.9927
# Epoch 326/500
# ...
# Epoch 392/500
# 28/28 [==============================] - 1s 36ms/step - loss: 9.0100e-04 - accuracy: 0.9996 - val_loss: 0.0670 - val_accuracy: 0.9931
# Epoch 393/500
# 28/28 [==============================] - 1s 34ms/step - loss: 8.4393e-04 - accuracy: 0.9997 - val_loss: 0.0680 - val_accuracy: 0.9930
# Epoch 394/500
# 28/28 [==============================] - 1s 35ms/step - loss: 8.9159e-04 - accuracy: 0.9996 - val_loss: 0.0720 - val_accuracy: 0.9929
# Epoch 395/500
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0668 - val_accuracy: 0.9931
# Epoch 497/500
# 28/28 [==============================] - 1s 34ms/step - loss: 9.6466e-04 - accuracy: 0.9996 - val_loss: 0.0696 - val_accuracy: 0.9930
# Epoch 498/500
# 28/28 [==============================] - 1s 35ms/step - loss: 9.3181e-04 - accuracy: 0.9996 - val_loss: 0.0684 - val_accuracy: 0.9930
# Epoch 499/500
# 28/28 [==============================] - 1s 35ms/step - loss: 9.6338e-04 - accuracy: 0.9996 - val_loss: 0.0689 - val_accuracy: 0.9931
# Epoch 500/500
# 28/28 [==============================] - 1s 35ms/step - loss: 8.1787e-04 - accuracy: 0.9997 - val_loss: 0.0696 - val_accuracy: 0.9931

# %%
plot_target = ['loss', 'val_loss']

plt.figure(figsize=(8,5))

for each in plot_target:
    plt.plot(history.history[each], label = each)
plt.ylim(0,1)
plt.legend(), plt.grid(), plt.show()
# Out:
# (<matplotlib.legend.Legend at 0x7f0154037bb0>, None, None)

# %% [markdown]
# <br>

# %% [markdown]
# ### evaluate

# %%
loss, acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 1/1 - 2s - loss: 0.3521 - accuracy: 0.9109 - 2s/epoch - 2s/step

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

pred = model.predict(val_images)
pred = (pred > 0.5).astype(int)  # 임계값 설정

# 실제 라벨과 예측 라벨을 1차원 배열로 변환
true_labels = val_labels.flatten()
pred_labels = pred.flatten()

precision = precision_score(true_labels, pred_labels)
print("정밀도:", round(precision,3))

recall = recall_score(true_labels, pred_labels);
print("재현율:", round(recall,3))

f1 = f1_score(true_labels, pred_labels)
print("F1점수:", round(f1,3))
# Out:
# 5/5 [==============================] - 2s 17ms/step
# 2024-01-21 10:31:52.353369: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.20GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 정밀도: 0.833
# 재현율: 0.678
# F1점수: 0.748

# %%
num = 6

test_image = test_images[num]
test_label = test_labels[num]
prediction = model.predict(np.expand_dims(test_image, axis=0))[0]
prediction = np.where(prediction > 0.5, 1, 0)
diff= abs(test_label-prediction[:,:,0])
count = np.count_nonzero(diff==1)
print("diff: ",count)

plt.figure(figsize=(6,4))
plt.subplot(141) ;  plt.imshow(test_image, cmap='gray') ; plt.title('image');plt.axis('off')
plt.subplot(142) ;  plt.imshow(test_label, cmap='gray') ; plt.title('label'); plt.axis('off')
plt.subplot(143) ;  plt.imshow(prediction, cmap='gray') ; plt.title('Pred'); plt.axis('off')
plt.subplot(144) ; plt.imshow(diff, cmap='gray'); plt.title('diff') ; plt.axis('off')
plt.tight_layout();plt.show()
# Out:
# 1/1 [==============================] - 1s 984ms/step
# diff:  4975

# %% [markdown]
# ### test dataset에서 틀린 픽셀 수

# %%
test_images.shape
# Out:
# (19, 256, 256, 3)

# %%
diff_counts = []

for i in range(len(test_images)):
    test_image = test_images[i]
    test_label = test_labels[i]
    prediction = model.predict(np.expand_dims(test_image, axis=0))[0]
    prediction = np.where(prediction > 0.5, 1, 0)
    diff = abs(test_label-prediction[:,:,0])
    count = np.count_nonzero(diff==1)
    diff_counts.append(count)

total = sum(diff_counts)
print("total diff: ", total)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# total diff:  110939

# %% [markdown]
# - 채도를 건들었더니 오차가 15000개가 넘어가서 채도는 뺏다

# %% [markdown]
# <br>

# %% [markdown]
# ### 모델 저장

# %%
#model.save('.../seg.h5')
